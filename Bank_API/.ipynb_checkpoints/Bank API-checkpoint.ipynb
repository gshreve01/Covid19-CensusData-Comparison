# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from config import gkey

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {
    "location": "35.2274877,-80.8622282", 
    "radius": 5000,
    "type": "bank",
     "key": gkey
}

response = requests.get(base_url, params=params)
bank_data = response.json()
print(f'{response}')
# Bank_info =[]
# for bank_dict in bank_data['results']:
    
#     try:

#         bank_data = response.json()
#         bank_name = bank_dict['name']
#         bank_lat=bank_dict['geometry']['location']['lat']
#         bank_lng=bank_dict['geometry']['location']['lng']
#         bank_rating = bank_dict['rating']
#         bank_types =bank_dict['types']
#         bank_address=bank_dict["vicinity"]
#         Bank_info.append({"Bank_Name":bank_name,
#                          "Lat":bank_lat,
#                          "Lng":bank_lng,
#                          "Rating":bank_rating,
#                          "Bank_Types":bank_types,
#                          "Bank_address":bank_address})
#     except KeyError:
#               print("Not found")
#               pass               

print(json.dumps(bank_data['results'], indent=4, sort_keys=True))
# Out:
# <Response [200]>
# [
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.2274061,
#                 "lng": -80.8421864
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.22884863029149,
#                     "lng": -80.8410003697085
#                 },
#                 "southwest": {
#                     "lat": 35.2261506697085,
#                     "lng": -80.8436983302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "7e22a0db9394265531fe90b2a5b2b5acfe18f4e7",
#         "name": "Bank of America Financial Center",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 3872,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/101404291636870301524\">Luis Ollarves</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAUItsPdn-IJjscd6m-B9_eC06VUdK1eTRXbkLsIVZWVzclrHAUuoTEhGOussSiyUZQzthKscuyj-X2V9__nbSoFasI3DDpBuXu96Y9b1Lb_l_T9TITHa_M8aUC3DHsEQ_EhAB6fcJq_vl3ZJDCG0qc1J-GhQlxejyXcB48anzmIn-mmVMi7fjew",
#                 "width": 2592
#             }
#         ],
#         "place_id": "ChIJMaMPcyWgVogROuj5tD7dT0M",
#         "plus_code": {
#             "compound_code": "65G5+X4 Charlotte, NC, United States",
#             "global_code": "867X65G5+X4"
#         },
#         "rating": 2.1,
#         "reference": "ChIJMaMPcyWgVogROuj5tD7dT0M",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 89,
#         "vicinity": "100 North Tryon Street #170, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.2154347,
#                 "lng": -80.83401200000002
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.21683068029149,
#                     "lng": -80.8328494197085
#                 },
#                 "southwest": {
#                     "lat": 35.21413271970849,
#                     "lng": -80.8355473802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#         "id": "df04a6b47e8443c407640d1cd29b69a8c8b98060",
#         "name": "State Employees\u2019 Credit Union",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 586,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/114237399048986834336\">Hardik Chudasama</a>"
#                 ],
#                 "photo_reference": "CmRaAAAA4-NYqUuTDZaXAmjElhkcvLB7jvDNVsDl9dPb3vhJG1mVZgr12RIillqZx0Ewe78ToBb3ycqGP7V5Mfe6egRQpVa7QbP_OlKdhKHQLejD3GxCLO4utPs1ibPFi9ytNQ_YEhCZ0CJLWlscdsua0OzVa2m1GhTz6EgqIcN-U5S1drNgMaIAd7sV6Q",
#                 "width": 797
#             }
#         ],
#         "place_id": "ChIJ5XYI4oqfVogRtMOI1NM-V_E",
#         "plus_code": {
#             "compound_code": "6588+59 Charlotte, NC, United States",
#             "global_code": "867X6588+59"
#         },
#         "rating": 4.1,
#         "reference": "ChIJ5XYI4oqfVogRtMOI1NM-V_E",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 25,
#         "vicinity": "1130 East 3rd Street, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.2083169,
#                 "lng": -80.8228768
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.2097174302915,
#                     "lng": -80.82160561970848
#                 },
#                 "southwest": {
#                     "lat": 35.2070194697085,
#                     "lng": -80.8243035802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "91ee5b2b67dc825767b6c88051272df1bff40087",
#         "name": "PNC Bank",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 1192,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/110443944727647575205\">PNC Bank</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAafT-9ftg4WQwJM8DSg4Dr7uL5jc99b8elPgvwhmowJbSJ7B_Y-7np6FMHnc4DvPltcV1fVB0H183peCJNjzLE-KHu6taFSDjcHfQKRCKx3MJivzSI-S0bjy6NxWAe87-EhAWqXcF_Odn1SBXGzYPaeCuGhSP6f5i4cpQ_X0Qbuij_Ldf2eZbZA",
#                 "width": 2119
#             }
#         ],
#         "place_id": "ChIJDcd6zvGfVogROuIfXPSZGFo",
#         "plus_code": {
#             "compound_code": "655G+8R Charlotte, NC, United States",
#             "global_code": "867X655G+8R"
#         },
#         "rating": 3.8,
#         "reference": "ChIJDcd6zvGfVogROuIfXPSZGFo",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "atm",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 8,
#         "vicinity": "2000 Randolph Road, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.215413,
#                 "lng": -80.832115
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.2168056302915,
#                     "lng": -80.8309023697085
#                 },
#                 "southwest": {
#                     "lat": 35.2141076697085,
#                     "lng": -80.8336003302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "0a84b8774e446e653fd555c8fa6a312dfd633db2",
#         "name": "SunTrust",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 1667,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/101310976677108809483\">SunTrust</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAVjJy6agJcVKt5aY5x-M3ZjzvGfFw0ou653FUOypKtDlTfIedR7lmBxaM23PjpGQzRgKzhO6jwSHdKVmmRWj8mcCp7GtCDvHH9A9kqW5sKXAkP1LzbgxhaKIJdG70jRkUEhAImGtxAvSwgqSi_YT4Ag1aGhQY_id6Pcz9IQkGzYOZydTsKXFSDQ",
#                 "width": 1667
#             }
#         ],
#         "place_id": "ChIJ-VbjKvWfVogRUU1ZYRwewmY",
#         "plus_code": {
#             "compound_code": "6589+55 Charlotte, NC, United States",
#             "global_code": "867X6589+55"
#         },
#         "rating": 2.7,
#         "reference": "ChIJ-VbjKvWfVogRUU1ZYRwewmY",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "atm",
#             "finance",
#             "insurance_agency",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 13,
#         "vicinity": "101 South Kings Drive, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.22868049999999,
#                 "lng": -80.8416694
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.22988573029149,
#                     "lng": -80.84016811970848
#                 },
#                 "southwest": {
#                     "lat": 35.22718776970849,
#                     "lng": -80.8428660802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "7c1102b0fccb8025c3beedbace772235a8d9cfb0",
#         "name": "Fifth Third Bank & ATM",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 3024,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/111021782299736672636\">Joseph K.</a>"
#                 ],
#                 "photo_reference": "CmRaAAAANmrP2YonLXaJn6yKCs0NZc8itOusc_lGtmGdGGiwFvJoJHBbYdHc1J0ppTp85e0WquMvOb3ICukhssVq2bHQo2cBbf_1TKdiq26tI17mdqQVg1ujb2SmSe0Cl6qz_W80EhAYeY4ErZO42khfFMlaZOyQGhSKTxUaYoN1mMqTl6rQF-E0CMvm5w",
#                 "width": 4032
#             }
#         ],
#         "place_id": "ChIJCY8EEy-gVogRStAl0e4g_sM",
#         "plus_code": {
#             "compound_code": "65H5+F8 Charlotte, NC, United States",
#             "global_code": "867X65H5+F8"
#         },
#         "rating": 3.5,
#         "reference": "ChIJCY8EEy-gVogRStAl0e4g_sM",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "atm",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 4,
#         "vicinity": "201 North Tryon Street, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.19724230000001,
#                 "lng": -80.82627649999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.1986381802915,
#                     "lng": -80.8251060697085
#                 },
#                 "southwest": {
#                     "lat": 35.1959402197085,
#                     "lng": -80.8278040302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "1df5f6a3082053fa0bbe5ae69af2d490ac52982c",
#         "name": "Wells Fargo Bank",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 500,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/114814204606618077103\">Wells Fargo Bank</a>"
#                 ],
#                 "photo_reference": "CmRaAAAA1ATwpUk8AfSmUxR0gnMaWWViJ9gE6vDT-EqVxo3PnUep2R0ySPRHv7keRgpPG_rkUEqR8JL83uCvUfHKLM3Y9qarbVLDh5-tTYGaBPa1bFAb0fMNZld0-Wen8kadXNzdEhDOVX3Y-jgBE6Jzh-Lwq2mRGhS04TUumMydUQUdT_jNyn6QtiGIKg",
#                 "width": 500
#             }
#         ],
#         "place_id": "ChIJIViQjOmfVogRLrxDUqvNBF4",
#         "plus_code": {
#             "compound_code": "55WF+VF Charlotte, NC, United States",
#             "global_code": "867X55WF+VF"
#         },
#         "rating": 2.3,
#         "reference": "ChIJIViQjOmfVogRLrxDUqvNBF4",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "atm",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 6,
#         "vicinity": "839 Providence Road, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.2129016,
#                 "lng": -80.8333768
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.21432273029149,
#                     "lng": -80.83202586970849
#                 },
#                 "southwest": {
#                     "lat": 35.21162476970849,
#                     "lng": -80.83472383029151
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "2bb62f4da1940f6b8a895115a4f799b621e28ef3",
#         "name": "Bank of America (with Drive-thru ATM)",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 250,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/115222522662926594765\">Bank of America (with Drive-thru ATM)</a>"
#                 ],
#                 "photo_reference": "CmRaAAAALHLBbpi5hpQfVQoVCBMltEaS_rQBtKOMvriT9hwrg14aPGtvdOBtbIRinETjBZ6gSAyPWfvNSWbFl0SfYM-RXkXwRaF7gHoGArV04uxQs0DV-Z59Re7zdN6qsNS9VRFPEhDqFLRJrZRhkLdKhuq41Vq6GhRFRnYDad0xUsFttvS_piD4mF-v-w",
#                 "width": 250
#             }
#         ],
#         "place_id": "ChIJq4PLYIufVogRPxTrRbWtAwI",
#         "plus_code": {
#             "compound_code": "6578+5J Charlotte, NC, United States",
#             "global_code": "867X6578+5J"
#         },
#         "rating": 2,
#         "reference": "ChIJq4PLYIufVogRPxTrRbWtAwI",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 19,
#         "vicinity": "301 South Kings Drive, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.23941070000001,
#                 "lng": -80.8871971
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.2406346802915,
#                     "lng": -80.8858747197085
#                 },
#                 "southwest": {
#                     "lat": 35.23793671970851,
#                     "lng": -80.8885726802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "6eaa99988e5c1f5dab2eb4717c233a029fb1732e",
#         "name": "First Citizens Bank",
#         "opening_hours": {
#             "open_now": false
#         },
#         "place_id": "ChIJC4sI8O2hVogRt-CMsUrbJJU",
#         "plus_code": {
#             "compound_code": "64Q7+Q4 Charlotte, NC, United States",
#             "global_code": "867X64Q7+Q4"
#         },
#         "rating": 1.5,
#         "reference": "ChIJC4sI8O2hVogRt-CMsUrbJJU",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 8,
#         "vicinity": "1024 Alleghany Street, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.2208849,
#                 "lng": -80.8250037
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.2222137802915,
#                     "lng": -80.8237442697085
#                 },
#                 "southwest": {
#                     "lat": 35.2195158197085,
#                     "lng": -80.8264422302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "1c00df6caeee0daf6a12e4eec136a24ba10fd2e6",
#         "name": "Charlotte Metro Credit Union",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 350,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/100897251592361705838\">Charlotte Metro Credit Union</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAVwkPAs_E8p78VHQ-eiGZTe_cJMMpM6N0kv2eZiMZagMaBXmxN5wXFL4Maq83-xegMrD0vEP5o4UFuw3l9miuIop9n-R10tYf_bJe3CP2xg5z-d3Co--2kpL-YCyPQC-3EhBLfTv8ZMMGACxMmc3h3gJ-GhSfgFQGojsXb51gNFArt1o2r8EoIA",
#                 "width": 350
#             }
#         ],
#         "place_id": "ChIJ5_xKNxygVogR6dHRhDUowfk",
#         "plus_code": {
#             "compound_code": "65CF+9X Charlotte, NC, United States",
#             "global_code": "867X65CF+9X"
#         },
#         "rating": 3.1,
#         "reference": "ChIJ5_xKNxygVogR6dHRhDUowfk",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "atm",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 57,
#         "vicinity": "718 Central Avenue, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.2228448,
#                 "lng": -80.8391924
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.2244456302915,
#                     "lng": -80.83752151970849
#                 },
#                 "southwest": {
#                     "lat": 35.2217476697085,
#                     "lng": -80.8402194802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "3c21f2b5d90b9770becd7208de0f7e4f3b814f57",
#         "name": "Federal Reserve Bank",
#         "photos": [
#             {
#                 "height": 5344,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/111234827342893930551\">Johanna Vargas</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAU-wFHglrJaUpr13SuKtFyv5zCd_a4Xktat2EUoPO0tXte3uM4UNppdCj-QAZr4HH87NCL_IUWi98lZ_LUqg17YYRhjcuHkq_43YzYOgWv7nUfz0sEkNX0poXvxalQIoZEhBDbd_1e9_vZCC1UoRtw8duGhReKNkRqmcpW_Q9ebmD9mit8TPX1Q",
#                 "width": 3006
#             }
#         ],
#         "place_id": "ChIJ_2haviagVogRbJiHpQ9RPOE",
#         "plus_code": {
#             "compound_code": "65F6+48 Charlotte, NC, United States",
#             "global_code": "867X65F6+48"
#         },
#         "rating": 3.8,
#         "reference": "ChIJ_2haviagVogRbJiHpQ9RPOE",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 6,
#         "vicinity": "530 East Trade Street, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.21244,
#                 "lng": -80.835393
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.2138246302915,
#                     "lng": -80.83416816970849
#                 },
#                 "southwest": {
#                     "lat": 35.2111266697085,
#                     "lng": -80.83686613029151
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "17e572b0a9339f1b74f8b6d7dc30278b4dc28c95",
#         "name": "NewDominion Bank: Metro Office",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 1000,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/112925836675894011750\">NewDominion Bank: Metro Office</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAfUpylx6Rv9fQNweOkvIIbOnyMahF8ztX51tiCjPIouhoEmdUYumsU5GSjgpgrAIpXE3xDiu8eBsIeFJIC36P9tYCVRVAdBxe6IAp72qRODKtvXS9w0iHrQviPe_ACZ11EhCixLnEWzdN88CSfXeEQY49GhR6tqzRcBsL_WGNZByWs11O2xSXjg",
#                 "width": 1500
#             }
#         ],
#         "place_id": "ChIJE5P8e4yfVogR7aKqGs_WfbA",
#         "plus_code": {
#             "compound_code": "6567+XR Charlotte, NC, United States",
#             "global_code": "867X6567+XR"
#         },
#         "rating": 4.8,
#         "reference": "ChIJE5P8e4yfVogR7aKqGs_WfbA",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "atm",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 17,
#         "vicinity": "1111 Metropolitan Avenue # 100, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.2254267,
#                 "lng": -80.89107469999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.2266666302915,
#                     "lng": -80.88981491970848
#                 },
#                 "southwest": {
#                     "lat": 35.2239686697085,
#                     "lng": -80.8925128802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "a6995ff11eb17c03a39a542e44e94c8537545a98",
#         "name": "Fifth Third Bank & ATM",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 311,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/117734067083012358487\">Fifth Third Bank &amp; ATM</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAxK1KriVPKSFaJb1dzB8ahR-c3w50O42fqpjMt-ePyZcr62c6X4Xl0eu9yZV5MqXEg28SDC60G-OqbsJp3QzvP-vi8gUw5ny6Fd4RrdYDW91alJuliRjtq6O60AonIc5CEhCA-AYWWf_oxclvMpxTB0s5GhQnccJxRx1CxQ0hTaqPenMZmsV6Qg",
#                 "width": 554
#             }
#         ],
#         "place_id": "ChIJj-iDYPyhVogRxlxLq7nc-vE",
#         "plus_code": {
#             "compound_code": "64G5+5H Charlotte, NC, United States",
#             "global_code": "867X64G5+5H"
#         },
#         "rating": 3.2,
#         "reference": "ChIJj-iDYPyhVogRxlxLq7nc-vE",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "atm",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 14,
#         "vicinity": "2752 Ashley Road, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.2264103,
#                 "lng": -80.84113599999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.22789453029149,
#                     "lng": -80.83989771970849
#                 },
#                 "southwest": {
#                     "lat": 35.22519656970849,
#                     "lng": -80.84259568029151
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "ce01de46c9443ef3c62e98d1574749ae0055e5cd",
#         "name": "Bank of America Private Bank",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 275,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/101339113374024962870\">Bank of America Private Bank</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAb9WAEdCqL4LvRSbxOiAV0-NuMJ4imwuiR7HVEfNJcGzacxAH00fsFAtujzWcsrL7_9h9qFEwFTKOBLYx3IwGNKx6Wr9ZVp0tnfndUfF9TdC7IazNXtxC99_P75RmYwrNEhDxPOiY7oczmq7T6Ka5eK-1GhRvyvbRRo4cYYTGM_EGLgA25AzSLg",
#                 "width": 949
#             }
#         ],
#         "place_id": "ChIJQWL9fi-gVogRoL-CmJGdOW4",
#         "plus_code": {
#             "compound_code": "65G5+HG Charlotte, NC, United States",
#             "global_code": "867X65G5+HG"
#         },
#         "rating": 5,
#         "reference": "ChIJQWL9fi-gVogRoL-CmJGdOW4",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 1,
#         "vicinity": "150 North College Street, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.2651669,
#                 "lng": -80.8544928
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.2665192302915,
#                     "lng": -80.8533174697085
#                 },
#                 "southwest": {
#                     "lat": 35.2638212697085,
#                     "lng": -80.8560154302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "cf6d1807df8cc7a0860fb40a9afa9b63f2f1577a",
#         "name": "Bank of America (with Drive-thru ATM)",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 250,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/111887759873603247979\">Bank of America (with Drive-thru ATM)</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAcYVhFKB4pynivLSCqs4jkPEV49UWEEAVwwkV_PtG-cg6csDIO6H9tckc4nbR-1Cyd_FVL_SyiOSt0wF7ZoJTmIXdm6lqVlkKMu8iLxtvsX13OMYfCi7tEen31a7Z8-3AEhAEpDXdi9xFW8lts6b7FmvqGhQjdv_uG7QglTA5xWn1oLL98y4Miw",
#                 "width": 250
#             }
#         ],
#         "place_id": "ChIJ-8w-oRpw54gRTPocDur6Zso",
#         "plus_code": {
#             "compound_code": "748W+36 Charlotte, NC, United States",
#             "global_code": "867X748W+36"
#         },
#         "rating": 3.7,
#         "reference": "ChIJ-8w-oRpw54gRTPocDur6Zso",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 19,
#         "vicinity": "2249 Beatties Ford Road, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.1983429,
#                 "lng": -80.826764
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.19967183029151,
#                     "lng": -80.8253472697085
#                 },
#                 "southwest": {
#                     "lat": 35.19697386970851,
#                     "lng": -80.82804523029151
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "2e6b91f764be11f07a9c4ea67ad7696bf8136fc7",
#         "name": "First Citizens Bank",
#         "opening_hours": {
#             "open_now": false
#         },
#         "place_id": "ChIJrxrOgOmfVogRDoajHMI0aKI",
#         "plus_code": {
#             "compound_code": "55XF+87 Charlotte, NC, United States",
#             "global_code": "867X55XF+87"
#         },
#         "rating": 2.1,
#         "reference": "ChIJrxrOgOmfVogRDoajHMI0aKI",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 7,
#         "vicinity": "802 Providence Road, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.225425,
#                 "lng": -80.844037
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.22653113029149,
#                     "lng": -80.84259986970848
#                 },
#                 "southwest": {
#                     "lat": 35.2238331697085,
#                     "lng": -80.8452978302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "58f67405965287b4e05a7eb31e51640076e455c5",
#         "name": "BB&T Investment Services Inc",
#         "opening_hours": {
#             "open_now": false
#         },
#         "place_id": "ChIJQU-kXC-gVogRQGGfrAjH6to",
#         "plus_code": {
#             "compound_code": "65G4+59 Charlotte, NC, United States",
#             "global_code": "867X65G4+59"
#         },
#         "rating": 1.5,
#         "reference": "ChIJQU-kXC-gVogRQGGfrAjH6to",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "atm",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 8,
#         "vicinity": "200 South College Street, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.2268851,
#                 "lng": -80.8442379
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.22802718029149,
#                     "lng": -80.84291746970848
#                 },
#                 "southwest": {
#                     "lat": 35.22532921970849,
#                     "lng": -80.84561543029149
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "4ffd80f97462c795ffbc639704b54c3b977e97c2",
#         "name": "First Citizens Bank",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 3024,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/108239009381599746966\">Ryan Whitmore</a>"
#                 ],
#                 "photo_reference": "CmRaAAAA1b0N6sZSJR0R2S6KxhX2ZZqP8eqWM-0DUqV4sRQiB8g1DQ9YoBhOOFF3fChvOOG9vHHFRTf4l8TOYtHExmakHD4kO-Xb7-hWcPdToOfHZNjnTjjWShleMwp4SrXLANOMEhCbBwv4ZJtB75eVellvvYsgGhSgVra8fs-pEFxioitkajaN2wtCGg",
#                 "width": 4032
#             }
#         ],
#         "place_id": "ChIJMaMPcyWgVogRmFx9i08K1v4",
#         "plus_code": {
#             "compound_code": "65G4+Q8 Charlotte, NC, United States",
#             "global_code": "867X65G4+Q8"
#         },
#         "rating": 2.6,
#         "reference": "ChIJMaMPcyWgVogRmFx9i08K1v4",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 10,
#         "vicinity": "128 South Tryon Street, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.22126079999999,
#                 "lng": -80.8232675
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.22269773029149,
#                     "lng": -80.82208506970849
#                 },
#                 "southwest": {
#                     "lat": 35.21999976970849,
#                     "lng": -80.8247830302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "933a3a3a7ca8d5de90b2dbb63bbe0ca6d2a46ced",
#         "name": "Charlotte Metro Credit Union Drive Thru",
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 350,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/115750812229178764798\">Charlotte Metro Credit Union Drive Thru</a>"
#                 ],
#                 "photo_reference": "CmRaAAAAPNSZbFGsMPr7jWDCh8GhIsmi7pIRumqFyg7Ibv6bQRkK8IaQG8t-x8Tp4K7QNdRk7tHm7W6Nxjo17HIHtkS9csCySs0bLsAF6Y5kLtoYsm8CmcrK2yJA2SKCsjLMQzpxEhAgsIwUXVDUkk8Go6f6w9jdGhR_z8UZarptI4q3tdR8ys3Lv3l7UA",
#                 "width": 350
#             }
#         ],
#         "place_id": "ChIJlX0m8xygVogRwlKPQyUoun8",
#         "plus_code": {
#             "compound_code": "65CG+GM Charlotte, NC, United States",
#             "global_code": "867X65CG+GM"
#         },
#         "rating": 3,
#         "reference": "ChIJlX0m8xygVogRwlKPQyUoun8",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "atm",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 5,
#         "vicinity": "818 Central Avenue, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.226074,
#                 "lng": -80.8440336
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.22756373029149,
#                     "lng": -80.8428301197085
#                 },
#                 "southwest": {
#                     "lat": 35.22486576970849,
#                     "lng": -80.84552808029152
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "c1758dd52336a81f9429fec837a17c31199d071f",
#         "name": "Blue Point Capital Partners",
#         "place_id": "ChIJlyR9bi-gVogRG5QatfuNGBA",
#         "plus_code": {
#             "compound_code": "65G4+C9 Charlotte, NC, United States",
#             "global_code": "867X65G4+C9"
#         },
#         "reference": "ChIJlyR9bi-gVogRG5QatfuNGBA",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "atm",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "vicinity": "201 South Tryon Street, Charlotte"
#     },
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.23478220000001,
#                 "lng": -80.8800219
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.23608748029149,
#                     "lng": -80.8787387197085
#                 },
#                 "southwest": {
#                     "lat": 35.2333895197085,
#                     "lng": -80.8814366802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "c5b7e873374f44195ce10cdb1c09b9ec56b0db9f",
#         "name": "Bank of America ATM",
#         "place_id": "ChIJEeQ38e2hVogRkWPxomQYrfM",
#         "plus_code": {
#             "compound_code": "64M9+WX Charlotte, NC, United States",
#             "global_code": "867X64M9+WX"
#         },
#         "rating": 3.5,
#         "reference": "ChIJEeQ38e2hVogRkWPxomQYrfM",
#         "scope": "GOOGLE",
#         "types": [
#             "bank",
#             "atm",
#             "finance",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 2,
#         "vicinity": "2405 Freedom Drive, Charlotte"
#     }
# ]

# %%
print(f'{Bank_info}')
len(Bank_info)
# Out:
# []
# 0
